# %%
from sklearn.datasets import load_iris # built in iris dataset
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.tree import plot_tree # for plotting the decision tree
import matplotlib.pyplot as plt

# %%
# loading iris data
iris=load_iris()
x=iris.data # features 
y=iris.target # labels

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
# 80-20 split for training and testing
# random_state=42

# %%
model=DecisionTreeClassifier(max_depth=3) # tree depth is 3

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
pdt=model.predict(x_test)

# %%
acc=accuracy_score(y_test,pdt)
print(acc)
# Out:
# 1.0

# %%
print(classification_report(y_test,pdt,target_names=iris.target_names)) 
# prints the classification report for the test set
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       1.00      1.00      1.00         8
#    virginica       1.00      1.00      1.00        12
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
# now visualizing the tree
plt.figure(figsize=(8,8))
plot_tree(
    model,
    feature_names=iris.feature_names,
    class_names=iris.target_names,
    filled=True,
    rounded=True
)
# Out:
# [Text(0.375, 0.875, 'petal width (cm) <= 0.8\ngini = 0.666\nsamples = 120\nvalue = [40, 42, 38]\nclass = versicolor'),
#  Text(0.25, 0.625, 'gini = 0.0\nsamples = 40\nvalue = [40, 0, 0]\nclass = setosa'),
#  Text(0.3125, 0.75, 'True  '),
#  Text(0.5, 0.625, 'petal length (cm) <= 4.75\ngini = 0.499\nsamples = 80\nvalue = [0, 42, 38]\nclass = versicolor'),
#  Text(0.4375, 0.75, '  False'),
#  Text(0.25, 0.375, 'petal width (cm) <= 1.65\ngini = 0.051\nsamples = 38\nvalue = [0, 37, 1]\nclass = versicolor'),
#  Text(0.125, 0.125, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]\nclass = versicolor'),
#  Text(0.375, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.75, 0.375, 'petal width (cm) <= 1.75\ngini = 0.21\nsamples = 42\nvalue = [0, 5, 37]\nclass = virginica'),
#  Text(0.625, 0.125, 'gini = 0.5\nsamples = 8\nvalue = [0, 4, 4]\nclass = versicolor'),
#  Text(0.875, 0.125, 'gini = 0.057\nsamples = 34\nvalue = [0, 1, 33]\nclass = virginica')]
